# %%
import rasterio
import matplotlib.pyplot as plt

# Open DEM file
dem_fp = r'E:/Swiss/terrain/swissalti3d_2021_2505-1138_0.5_2056_5728.tif'
dem = rasterio.open(dem_fp)
dem
data = dem.read()
data
# Out:
# array([[[478.55786, 478.5374 , 478.51642, ..., 453.08618, 453.10498,
#          453.1381 ],
#         [478.58655, 478.5021 , 478.48657, ..., 453.07684, 453.08176,
#          453.11624],
#         [478.56302, 478.55405, 478.46133, ..., 453.03427, 453.06357,
#          453.07587],
#         ...,
#         [446.62613, 446.5264 , 446.53815, ..., 428.14258, 428.05222,
#          428.02298],
#         [446.62167, 446.61517, 446.56766, ..., 428.1337 , 428.13855,
#          428.075  ],
#         [446.61722, 446.61707, 446.58795, ..., 428.1302 , 428.1069 ,
#          428.1444 ]]], dtype=float32)

# %%
dem.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'float32',
#  'nodata': -9999.0,
#  'width': 2000,
#  'height': 2000,
#  'count': 1,
#  'crs': CRS.from_epsg(2056),
#  'transform': Affine(0.5, 0.0, 2505000.0,
#         0.0, -0.5, 1139000.0)}

# %%
dem.name
# Out:
# 'E:/Swiss/terrain/swissalti3d_2021_2505-1138_0.5_2056_5728.tif'

# %%
dem.count
# Out:
# 1

# %%
dem.shape
# Out:
# (2000, 2000)

# %%
data.size
# Out:
# 4000000

# %%
data.min()
# Out:
# 427.84113

# %%
data.max()
# Out:
# 478.58655

# %%
from rasterio.plot import show

# %%
with rasterio.open(dem_fp) as src:
    # Get the pixel size/resolution
    pixel_width, pixel_height = src.res
    # Print the resolution
    print(f"Pixel Size (Width x Height): {pixel_width} x {pixel_height} units")
# Out:
# Pixel Size (Width x Height): 0.5 x 0.5 units

# %%
show(dem, title='Vježba DEM')
# Out:
# <Axes: title={'center': 'Vježba DEM'}>

# %%
import rasterio
import matplotlib.pyplot as plt

ortho_fp = r'E:/Swiss/orto/swissimage-dop10_2020_2505-1138_2_2056.tif'
orto= rasterio.open(ortho_fp)
orto
datal = orto.read()
datal
# Out:
# array([[[171, 177, 183, ..., 120, 111,  79],
#         [171, 178, 175, ...,  81, 124,  85],
#         [161, 180, 182, ..., 105,  85, 120],
#         ...,
#         [158,  83,  98, ..., 149, 152, 149],
#         [111,  40,  67, ..., 151, 154, 148],
#         [138,  65,  58, ..., 152, 153, 145]],
#
#        [[160, 166, 172, ..., 136, 127,  95],
#         [160, 167, 167, ...,  97, 141, 102],
#         [153, 172, 174, ..., 122, 102, 137],
#         ...,
#         [163,  88, 103, ..., 138, 141, 140],
#         [116,  45,  72, ..., 140, 143, 139],
#         [143,  70,  63, ..., 141, 142, 136]],
#
#        [[142, 148, 154, ..., 107,  98,  66],
#         [142, 149, 148, ...,  68, 109,  70],
#         [134, 153, 155, ...,  90,  70, 105],
#         ...,
#         [156,  82,  99, ..., 110, 113, 111],
#         [109,  39,  68, ..., 112, 115, 110],
#         [137,  64,  59, ..., 113, 114, 107]]], dtype=uint8)

# %%
orto.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint8',
#  'nodata': None,
#  'width': 500,
#  'height': 500,
#  'count': 3,
#  'crs': CRS.from_epsg(2056),
#  'transform': Affine(2.0, 0.0, 2505000.0,
#         0.0, -2.0, 1139000.0)}

# %%
orto.name
# Out:
# 'E:/Swiss/orto/swissimage-dop10_2020_2505-1138_2_2056.tif'

# %%
from rasterio.plot import show

# %%
show(orto, title='Orto')
# Out:
# <Axes: title={'center': 'Orto'}>
